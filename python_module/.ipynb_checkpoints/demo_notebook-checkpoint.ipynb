# %% [markdown]
# ### On-line force capability evaluation based on efficient polytope vertex search
#
# Short script demonstrating usage of python module

# %%
import polytope_solver
import numpy as np

# %% [markdown]
# Define jacobian matrix and torque limits

# %%
J = np.array([[1, 0, 0, 0, 0, 0], [0, 1, 1, 0, 1, 0], [1, 0, 0, 1, 1, 1]])
t_min = np.array([[-1], [-1], [-1], [-1], [-1], [-1]])
t_max = np.array([[1], [1], [1], [1], [1], [1]])

# %% [markdown]
# Calculate the force polytope vertices
# ```
# t_min <  J^T.f < t_max
# ```

# %%
f_vert, polytopes = polytope_solver.force_polytope_ordered(J,t_min,t_max)

# %% [markdown]
# Visualise the vertices `f_vert`

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(f_vert[0,:],f_vert[1,:],f_vert[2,:])
for polygone in polytopes:
    plt.plot(polygone[0,:],polygone[1,:],polygone[2,:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.25">
